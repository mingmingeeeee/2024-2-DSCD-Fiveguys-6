# %% [markdown]
# <a href="https://colab.research.google.com/github/mingmingeeeee/2024-2-DSCD-Fiveguys-6/blob/main/%EC%9B%94%EB%B3%84_%EC%83%9D%ED%99%9C%EC%9D%B8%EA%B5%AC_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %%
df4_morning = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/04_morning.csv', encoding='CP949').reset_index()
df5_morning = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/05_morning.csv', encoding='CP949').reset_index()
df6_morning = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/06_morning.csv').reset_index()
df7_morning = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/07_morning.csv', encoding='CP949').reset_index()
df8_morning = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/08_morning.csv', encoding='CP949').reset_index()

df6_morning
# Out:
#        index     기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 0          0  20240601      7  11110515  15729.5092       537.2747
# 1          1  20240601      7  11110530  13981.0490       236.0333
# 2          2  20240601      7  11110540   4530.9439        67.5585
# 3          3  20240601      7  11110550  12945.3539       387.0220
# 4          4  20240601      7  11110560  19754.6092       625.3003
# ...      ...       ...    ...       ...         ...            ...
# 25435  25435  20240630      8  11680660  27278.7949      1640.7861
# 25436  25436  20240630      8  11650620  22755.5026       716.4574
# 25437  25437  20240630      8  11710690  24382.2153      2003.4601
# 25438  25438  20240630      8  11740610  46087.2532      1790.7827
# 25439  25439  20240630      8  11380690  57840.2394      2787.2033
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 0             342.3528         593.0943         449.7611         493.2852
# ...

# %%
df4_evening = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/04_evening.csv', encoding='CP949').reset_index()
df5_evening = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/05_evening.csv', encoding='CP949').reset_index()
df6_evening = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/06_evening.csv').reset_index()
df7_evening = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/07_evening.csv', encoding='CP949').reset_index()
df8_evening = pd.read_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/08_evening.csv', encoding='CP949').reset_index()

df6_evening
# Out:
#        index     기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 0          0  20240601     18  11560535  64349.6603      1599.3014
# 1          1  20240601     18  11740690   3271.2611        89.4500
# 2          2  20240601     18  11740590  11836.2625       854.1659
# 3          3  20240601     18  11740550  20703.6350      1987.8104
# 4          4  20240601     18  11740515  46065.6421      2572.6581
# ...      ...       ...    ...       ...         ...            ...
# 25435  25435  20240630     19  11410565  40456.3324       978.4310
# 25436  25436  20240630     19  11230660  31507.5296      1605.9749
# 25437  25437  20240630     19  11560630  18105.0352       412.2527
# 25438  25438  20240630     19  11200790  20359.0259       477.9859
# 25439  25439  20240630     19  11440590  21537.4951      1176.8876
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 0             628.3968         795.9178        1853.5619        3984.3833
# ...

# %%
df4_morning.drop(columns=['index', '총생활인구수'], inplace=True)
df5_morning.drop(columns=['index', '총생활인구수'], inplace=True)
df6_morning.drop(columns=['index', '총생활인구수'], inplace=True)
df7_morning.drop(columns=['index', '총생활인구수'], inplace=True)
df8_morning.drop(columns=['index', '총생활인구수'], inplace=True)

df8_morning.head()
# Out:
#       기준일ID  시간대구분     행정동코드  남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# 0  20240801      7  11200560       598.4276         343.9552         634.3103
# 1  20240801      7  11200535      1192.3184         345.0712         432.7680
# 2  20240801      7  11260620      1000.8753         536.5243         643.2819
# 3  20240801      7  11260610       796.6418         358.5987         463.0869
# 4  20240801      7  11410660       406.3222         276.6829         318.2294
#
#    남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  \
# 0         931.5964        1094.8525         894.0579        1159.5609  ...
# 1         751.3537        1086.7311        1067.1854        1238.4464  ...
# 2         639.9457         819.2556         801.8109         897.9527  ...
# 3         657.2952         940.1076         885.3741        1054.2720  ...
# 4         422.6130         442.4367         471.0784         572.6763  ...
#
# ...

# %%
df4_evening.drop(columns=['index', '총생활인구수'], inplace=True)
df5_evening.drop(columns=['index', '총생활인구수'], inplace=True)
df6_evening.drop(columns=['index', '총생활인구수'], inplace=True)
df7_evening.drop(columns=['index', '총생활인구수'], inplace=True)
df8_evening.drop(columns=['index', '총생활인구수'], inplace=True)

df8_evening.head()
# Out:
#       기준일ID  시간대구분     행정동코드  남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# 0  20240801     18  11740640       779.0215         402.2874         709.3603
# 1  20240801     18  11560670       217.3458         162.8229         191.5713
# 2  20240801     18  11740530       855.8601         653.4430         889.4190
# 3  20240801     18  11500570       649.6535         291.9787         415.6321
# 4  20240801     18  11740515      2394.1214        1469.3449        1358.0716
#
#    남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  \
# 0         544.9983         662.5453         749.4146         986.0083  ...
# 1         192.3894         254.9696         267.0676         442.6044  ...
# 2         660.8028         582.3629         536.8122         747.0616  ...
# 3         365.3556         561.9927         524.5178         646.0823  ...
# 4        1020.5190         990.3608         995.3501        2019.2213  ...
#
# ...

# %%
# 2. 평일 데이터만 필터링
df4_morning['기준일ID'] = pd.to_datetime(df4_morning['기준일ID'], format='%Y%m%d')
df4_morning = df4_morning[df4_morning['기준일ID'].dt.dayofweek < 5]
df5_morning['기준일ID'] = pd.to_datetime(df5_morning['기준일ID'], format='%Y%m%d')
df5_morning = df5_morning[df5_morning['기준일ID'].dt.dayofweek < 5]
df6_morning['기준일ID'] = pd.to_datetime(df6_morning['기준일ID'], format='%Y%m%d')
df6_morning = df6_morning[df6_morning['기준일ID'].dt.dayofweek < 5]
df7_morning['기준일ID'] = pd.to_datetime(df7_morning['기준일ID'], format='%Y%m%d')
df7_morning = df7_morning[df7_morning['기준일ID'].dt.dayofweek < 5]
df8_morning['기준일ID'] = pd.to_datetime(df8_morning['기준일ID'], format='%Y%m%d')
df8_morning = df8_morning[df8_morning['기준일ID'].dt.dayofweek < 5]

df8_morning
# Out:
#            기준일ID  시간대구분     행정동코드  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0     2024-08-01      7  11200560       598.4276         343.9552
# 1     2024-08-01      7  11200535      1192.3184         345.0712
# 2     2024-08-01      7  11260620      1000.8753         536.5243
# 3     2024-08-01      7  11260610       796.6418         358.5987
# 4     2024-08-01      7  11410660       406.3222         276.6829
# ...          ...    ...       ...            ...              ...
# 25435 2024-08-30      8  11740620       698.3795         266.7597
# 25436 2024-08-30      8  11740660       631.5190         379.6057
# 25437 2024-08-30      8  11740650       657.3703         228.0335
# 25438 2024-08-30      8  11740700      1383.1311         697.7267
# 25439 2024-08-30      8  11740690       442.1009         335.0672
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0             634.3103         931.5964        1094.8525         894.0579
# ...

# %%
# 2. 평일 데이터만 필터링
df4_evening['기준일ID'] = pd.to_datetime(df4_evening['기준일ID'], format='%Y%m%d')
df4_evening = df4_evening[df4_evening['기준일ID'].dt.dayofweek < 5]
df5_evening['기준일ID'] = pd.to_datetime(df5_evening['기준일ID'], format='%Y%m%d')
df5_evening = df5_evening[df5_evening['기준일ID'].dt.dayofweek < 5]
df6_evening['기준일ID'] = pd.to_datetime(df6_evening['기준일ID'], format='%Y%m%d')
df6_evening = df6_evening[df6_evening['기준일ID'].dt.dayofweek < 5]
df7_evening['기준일ID'] = pd.to_datetime(df7_evening['기준일ID'], format='%Y%m%d')
df7_evening = df7_evening[df7_evening['기준일ID'].dt.dayofweek < 5]
df8_evening['기준일ID'] = pd.to_datetime(df8_evening['기준일ID'], format='%Y%m%d')
df8_evening = df8_evening[df8_evening['기준일ID'].dt.dayofweek < 5]

df8_evening
# Out:
#            기준일ID  시간대구분     행정동코드  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0     2024-08-01     18  11740640       779.0215         402.2874
# 1     2024-08-01     18  11560670       217.3458         162.8229
# 2     2024-08-01     18  11740530       855.8601         653.4430
# 3     2024-08-01     18  11500570       649.6535         291.9787
# 4     2024-08-01     18  11740515      2394.1214        1469.3449
# ...          ...    ...       ...            ...              ...
# 25435 2024-08-30     19  11740650       869.2950         301.5477
# 25436 2024-08-30     19  11740640       804.8558         415.6287
# 25437 2024-08-30     19  11740700      1164.9393         587.6584
# 25438 2024-08-30     19  11740685      1513.0787         731.6731
# 25439 2024-08-30     19  11740690       121.6294          92.1823
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0             709.3603         544.9983         662.5453         749.4146
# ...

# %%
cols = ['기준일ID', '시간대구분', '행정동코드',
        '남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']

# %%
df4_morning_new = df4_morning[cols]
df5_morning_new = df5_morning[cols]
df6_morning_new = df6_morning[cols]
df7_morning_new = df7_morning[cols]
df8_morning_new = df8_morning[cols]

df8_morning_new
# Out:
#            기준일ID  시간대구분     행정동코드  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0     2024-08-01      7  11200560         634.3103         931.5964
# 1     2024-08-01      7  11200535         432.7680         751.3537
# 2     2024-08-01      7  11260620         643.2819         639.9457
# 3     2024-08-01      7  11260610         463.0869         657.2952
# 4     2024-08-01      7  11410660         318.2294         422.6130
# ...          ...    ...       ...              ...              ...
# 25435 2024-08-30      8  11740620         255.5090         630.9036
# 25436 2024-08-30      8  11740660         666.5261         808.6783
# 25437 2024-08-30      8  11740650         190.5588         569.0610
# 25438 2024-08-30      8  11740700         947.1743         664.5115
# 25439 2024-08-30      8  11740690        1006.1184         113.2301
#
#        남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  남자40세부터44세생활인구수  \
# 0            1094.8525         894.0579        1159.5609        1122.4140
# ...

# %%
df4_evening_new = df4_evening[cols]
df5_evening_new = df5_evening[cols]
df6_evening_new = df6_evening[cols]
df7_evening_new = df7_evening[cols]
df8_evening_new = df8_evening[cols]

df8_evening_new
# Out:
#            기준일ID  시간대구분     행정동코드  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0     2024-08-01     18  11740640         709.3603         544.9983
# 1     2024-08-01     18  11560670         191.5713         192.3894
# 2     2024-08-01     18  11740530         889.4190         660.8028
# 3     2024-08-01     18  11500570         415.6321         365.3556
# 4     2024-08-01     18  11740515        1358.0716        1020.5190
# ...          ...    ...       ...              ...              ...
# 25435 2024-08-30     19  11740650         369.4636         648.6220
# 25436 2024-08-30     19  11740640         616.3437         597.0503
# 25437 2024-08-30     19  11740700         599.6681         481.6438
# 25438 2024-08-30     19  11740685        1184.2853        1368.1816
# 25439 2024-08-30     19  11740690         238.1754         111.7177
#
#        남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  남자40세부터44세생활인구수  \
# 0             662.5453         749.4146         986.0083         813.3166
# ...

# %%
df4_morning_new['총_생활인구수'] = df4_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df4_morning_new = df4_morning_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df5_morning_new['총_생활인구수'] = df5_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df5_morning_new = df5_morning_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df6_morning_new['총_생활인구수'] = df6_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df6_morning_new = df6_morning_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df7_morning_new['총_생활인구수'] = df7_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df7_morning_new = df7_morning_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df8_morning_new['총_생활인구수'] = df8_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df8_morning_new = df8_morning_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df8_morning_new
# Out:
# <ipython-input-95-6d183ab4f703>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_morning_new['총_생활인구수'] = df4_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
# <ipython-input-95-6d183ab4f703>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5_morning_new['총_생활인구수'] = df5_morning_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
# <ipython-input-95-6d183ab4f703>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df4_evening_new['총_생활인구수'] = df4_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df4_evening_new = df4_evening_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df5_evening_new['총_생활인구수'] = df5_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df5_evening_new = df5_evening_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df6_evening_new['총_생활인구수'] = df6_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df6_evening_new = df6_evening_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df7_evening_new['총_생활인구수'] = df7_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df7_evening_new = df7_evening_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df8_evening_new['총_생활인구수'] = df8_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '남자60세부터64세생활인구수',
        '여자15세부터19세생활인구수',
       '여자20세부터24세생활인구수', '여자25세부터29세생활인구수', '여자30세부터34세생활인구수',
       '여자35세부터39세생활인구수', '여자40세부터44세생활인구수', '여자45세부터49세생활인구수',
       '여자50세부터54세생활인구수', '여자55세부터59세생활인구수', '여자60세부터64세생활인구수']].sum(axis=1)
df8_evening_new = df8_evening_new[['기준일ID', '시간대구분', '행정동코드', '총_생활인구수']]

df8_evening_new
# Out:
# <ipython-input-96-300314d08f52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_evening_new['총_생활인구수'] = df4_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
# <ipython-input-96-300314d08f52>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5_evening_new['총_생활인구수'] = df5_evening_new[['남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
# <ipython-input-96-300314d08f52>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
weekdays_4 = df4_morning_new['기준일ID'].nunique()
weekdays_5 = df5_morning_new['기준일ID'].nunique()
weekdays_6 = df6_morning_new['기준일ID'].nunique()
weekdays_7 = df7_morning_new['기준일ID'].nunique()
weekdays_8 = df8_morning_new['기준일ID'].nunique()

weekdays_6
# Out:
# 20

# %%
# 행정동코드별 한달 총 생활인구수 계산
df4_morning_final = df4_morning_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df4_morning_final['평일_일평균_생활인구수'] = df4_morning_final['총_생활인구수'] / weekdays_4
df4_morning_final = df4_morning_final.drop(columns = '총_생활인구수')

df4_morning_final = df4_morning_final.rename(columns={'행정동코드': '행정동_ID'})

# 5
df5_morning_final = df5_morning_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df5_morning_final['평일_일평균_생활인구수'] = df5_morning_final['총_생활인구수'] / weekdays_5
df5_morning_final = df5_morning_final.drop(columns = '총_생활인구수')

df5_morning_final = df5_morning_final.rename(columns={'행정동코드': '행정동_ID'})

# 6
df6_morning_final = df6_morning_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df6_morning_final['평일_일평균_생활인구수'] = df6_morning_final['총_생활인구수'] / weekdays_6
df6_morning_final = df6_morning_final.drop(columns = '총_생활인구수')

df6_morning_final = df6_morning_final.rename(columns={'행정동코드': '행정동_ID'})

# 7
df7_morning_final = df7_morning_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df7_morning_final['평일_일평균_생활인구수'] = df7_morning_final['총_생활인구수'] / weekdays_7
df7_morning_final = df7_morning_final.drop(columns = '총_생활인구수')

df7_morning_final = df7_morning_final.rename(columns={'행정동코드': '행정동_ID'})

# 8
df8_morning_final = df8_morning_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df8_morning_final['평일_일평균_생활인구수'] = df8_morning_final['총_생활인구수'] / weekdays_8
df8_morning_final = df8_morning_final.drop(columns = '총_생활인구수')

df8_morning_final = df8_morning_final.rename(columns={'행정동코드': '행정동_ID'})

df8_morning_final
# Out:
#        행정동_ID  평일_일평균_생활인구수
# 0    11110515  22735.733282
# 1    11110530  44307.547350
# 2    11110540   9930.365041
# 3    11110550  18048.719986
# 4    11110560  24374.269395
# ..        ...           ...
# 419  11740650  34248.882123
# 420  11740660  40288.121245
# 421  11740685  79441.702618
# 422  11740690   9023.339223
# 423  11740700  39359.680914
#
# [424 rows x 2 columns]

# %%
# 행정동코드별 한달 총 생활인구수 계산
df4_evening_final = df4_evening_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df4_evening_final['평일_일평균_생활인구수'] = df4_evening_final['총_생활인구수'] / weekdays_4
df4_evening_final = df4_evening_final.drop(columns = '총_생활인구수')

df4_evening_final = df4_evening_final.rename(columns={'행정동코드': '행정동_ID'})

# 5
df5_evening_final = df5_evening_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df5_evening_final['평일_일평균_생활인구수'] = df5_evening_final['총_생활인구수'] / weekdays_5
df5_evening_final = df5_evening_final.drop(columns = '총_생활인구수')

df5_evening_final = df5_evening_final.rename(columns={'행정동코드': '행정동_ID'})

# 6
df6_evening_final = df6_evening_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df6_evening_final['평일_일평균_생활인구수'] = df6_evening_final['총_생활인구수'] / weekdays_6
df6_evening_final = df6_evening_final.drop(columns = '총_생활인구수')

df6_evening_final = df6_evening_final.rename(columns={'행정동코드': '행정동_ID'})

# 7
df7_evening_final = df7_evening_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df7_evening_final['평일_일평균_생활인구수'] = df7_evening_final['총_생활인구수'] / weekdays_7
df7_evening_final = df7_evening_final.drop(columns = '총_생활인구수')

df7_evening_final = df7_evening_final.rename(columns={'행정동코드': '행정동_ID'})

# 8
df8_evening_final = df8_evening_new.groupby('행정동코드')['총_생활인구수'].sum().reset_index()

df8_evening_final['평일_일평균_생활인구수'] = df8_evening_final['총_생활인구수'] / weekdays_8
df8_evening_final = df8_evening_final.drop(columns = '총_생활인구수')

df8_evening_final = df8_evening_final.rename(columns={'행정동코드': '행정동_ID'})

df8_evening_final
# Out:
#        행정동_ID  평일_일평균_생활인구수
# 0    11110515  21163.024936
# 1    11110530  49817.442136
# 2    11110540   9776.715300
# 3    11110550  15371.468614
# 4    11110560  21164.824105
# ..        ...           ...
# 419  11740650  34695.568759
# 420  11740660  40606.983436
# 421  11740685  81617.825018
# 422  11740690   5011.141486
# 423  11740700  32911.968650
#
# [424 rows x 2 columns]

# %%
code = pd.read_csv('/content/drive/MyDrive/DSCD/data/행정동코드_매핑정보_20200325.csv', encoding='CP949')
code = code[['행자부행정동코드', '행정동명']]
code = code.drop(index=0).reset_index(drop=True)
code = code.rename(columns={'행자부행정동코드': '행정동_ID'})
code
# Out:
#        행정동_ID  행정동명
# 0    11110530   사직동
# 1    11110540   삼청동
# 2    11110550   부암동
# 3    11110560   평창동
# 4    11110570   무악동
# ..        ...   ...
# 419  11740690  둔촌1동
# 420  11740700  둔촌2동
# 421  11740570  암사1동
# 422  11740610  천호2동
# 423  11740685    길동
#
# [424 rows x 2 columns]

# %%
code = code.drop_duplicates()
code['행정동_ID'].nunique()
# Out:
# 424

# %%
code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정동_ID  424 non-null    object
#  1   행정동명    424 non-null    object
# dtypes: object(2)
# memory usage: 6.8+ KB

# %%
code['행정동_ID'] = code['행정동_ID'].astype(int)

# %%
merged_df_4 = df4_morning_final.merge(code, how='outer', on='행정동_ID')
merged_df_4 = merged_df_4.drop(columns = ['행정동_ID'])
merged_df_4 = merged_df_4.rename(columns={'행정동명': '행정동_명칭'})

merged_df_5 = df5_morning_final.merge(code, how='outer', on='행정동_ID')
merged_df_5 = merged_df_5.drop(columns = ['행정동_ID'])
merged_df_5 = merged_df_5.rename(columns={'행정동명': '행정동_명칭'})

merged_df_6 = df6_morning_final.merge(code, how='outer', on='행정동_ID')
merged_df_6 = merged_df_6.drop(columns = ['행정동_ID'])
merged_df_6 = merged_df_6.rename(columns={'행정동명': '행정동_명칭'})

merged_df_7 = df7_morning_final.merge(code, how='outer', on='행정동_ID')
merged_df_7 = merged_df_7.drop(columns = ['행정동_ID'])
merged_df_7 = merged_df_7.rename(columns={'행정동명': '행정동_명칭'})

merged_df_8 = df8_morning_final.merge(code, how='outer', on='행정동_ID')
merged_df_8 = merged_df_8.drop(columns = ['행정동_ID'])
merged_df_8 = merged_df_8.rename(columns={'행정동명': '행정동_명칭'})

merged_df_8
# Out:
#      평일_일평균_생활인구수 행정동_명칭
# 0    22735.733282  청운효자동
# 1    44307.547350    사직동
# 2     9930.365041    삼청동
# 3    18048.719986    부암동
# 4    24374.269395    평창동
# ..            ...    ...
# 419  34248.882123   성내2동
# 420  40288.121245   성내3동
# 421  79441.702618     길동
# 422   9023.339223   둔촌1동
# 423  39359.680914   둔촌2동
#
# [424 rows x 2 columns]

# %%
merged_df_4 = merged_df_4[~merged_df_4['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_5 = merged_df_5[~merged_df_5['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_6 = merged_df_6[~merged_df_6['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_7 = merged_df_7[~merged_df_7['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_8 = merged_df_8[~merged_df_8['행정동_명칭'].isin(['신사동', '일원2동'])]

merged_df_8
# Out:
#      평일_일평균_생활인구수 행정동_명칭
# 0    22735.733282  청운효자동
# 1    44307.547350    사직동
# 2     9930.365041    삼청동
# 3    18048.719986    부암동
# 4    24374.269395    평창동
# ..            ...    ...
# 419  34248.882123   성내2동
# 420  40288.121245   성내3동
# 421  79441.702618     길동
# 422   9023.339223   둔촌1동
# 423  39359.680914   둔촌2동
#
# [421 rows x 2 columns]

# %%
merged_df_4_evening = df4_evening_final.merge(code, how='outer', on='행정동_ID')
merged_df_4_evening = merged_df_4_evening.drop(columns = ['행정동_ID'])
merged_df_4_evening = merged_df_4_evening.rename(columns={'행정동명': '행정동_명칭'})

merged_df_5_evening = df5_evening_final.merge(code, how='outer', on='행정동_ID')
merged_df_5_evening = merged_df_5_evening.drop(columns = ['행정동_ID'])
merged_df_5_evening = merged_df_5_evening.rename(columns={'행정동명': '행정동_명칭'})

merged_df_6_evening = df6_evening_final.merge(code, how='outer', on='행정동_ID')
merged_df_6_evening = merged_df_6_evening.drop(columns = ['행정동_ID'])
merged_df_6_evening = merged_df_6_evening.rename(columns={'행정동명': '행정동_명칭'})

merged_df_7_evening = df7_evening_final.merge(code, how='outer', on='행정동_ID')
merged_df_7_evening = merged_df_7_evening.drop(columns = ['행정동_ID'])
merged_df_7_evening = merged_df_7_evening.rename(columns={'행정동명': '행정동_명칭'})

merged_df_8_evening = df8_evening_final.merge(code, how='outer', on='행정동_ID')
merged_df_8_evening = merged_df_8_evening.drop(columns = ['행정동_ID'])
merged_df_8_evening = merged_df_8_evening.rename(columns={'행정동명': '행정동_명칭'})

merged_df_8_evening
# Out:
#      평일_일평균_생활인구수 행정동_명칭
# 0    21163.024936  청운효자동
# 1    49817.442136    사직동
# 2     9776.715300    삼청동
# 3    15371.468614    부암동
# 4    21164.824105    평창동
# ..            ...    ...
# 419  34695.568759   성내2동
# 420  40606.983436   성내3동
# 421  81617.825018     길동
# 422   5011.141486   둔촌1동
# 423  32911.968650   둔촌2동
#
# [424 rows x 2 columns]

# %%
merged_df_4_evening = merged_df_4_evening[~merged_df_4_evening['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_5_evening = merged_df_5_evening[~merged_df_5_evening['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_6_evening = merged_df_6_evening[~merged_df_6_evening['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_7_evening = merged_df_7_evening[~merged_df_7_evening['행정동_명칭'].isin(['신사동', '일원2동'])]
merged_df_8_evening = merged_df_8_evening[~merged_df_8_evening['행정동_명칭'].isin(['신사동', '일원2동'])]

# %%
merged_df_8_evening
# Out:
#      평일_일평균_생활인구수 행정동_명칭
# 0    21163.024936  청운효자동
# 1    49817.442136    사직동
# 2     9776.715300    삼청동
# 3    15371.468614    부암동
# 4    21164.824105    평창동
# ..            ...    ...
# 419  34695.568759   성내2동
# 420  40606.983436   성내3동
# 421  81617.825018     길동
# 422   5011.141486   둔촌1동
# 423  32911.968650   둔촌2동
#
# [421 rows x 2 columns]

# %%
merged_df_4.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/04_morning_final.csv')
merged_df_5.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/05_morning_final.csv')
merged_df_6.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/06_morning_final.csv')
merged_df_7.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/07_morning_final.csv')
merged_df_8.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/08_morning_final.csv')

merged_df_4_evening.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/04_evening_final.csv')
merged_df_5_evening.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/05_evening_final.csv')
merged_df_6_evening.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/06_evening_final.csv')
merged_df_7_evening.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/07_evening_final.csv')
merged_df_8_evening.to_csv('/content/drive/MyDrive/DSCD/data/월별_행정동별_활동인구/08_evening_final.csv')
